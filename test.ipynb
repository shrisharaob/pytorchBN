# %%
run sparse_test.py
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/Documents/study/pytorchBN/proj/sparse_test.py in <module>
#     129     JI0 = 1.0
#     130     JII = -0.01
# --> 131     rnn = BalRNN(input_size,
#     132                  hidden_size,
#     133                  num_layers,
#
# ~/Documents/study/pytorchBN/proj/sparse_test.py in __init__(self, input_size, hidden_size, num_layers, batch_first, K, JI0, JII)
#      32         # ])
#      33
# ---> 34         self.weight_ih = nn.ParameterList([
#      35             nn.Parameter(
#      36                 self.initialize_ff_weight(input_size, hidden_size, K, JII))
#
# ~/Documents/study/pytorchBN/proj/sparse_test.py in <listcomp>(.0)
#      34         self.weight_ih = nn.ParameterList([
#      35             nn.Parameter(
# ---> 36                 self.initialize_ff_weight(input_size, hidden_size, K, JII))
# ...

# %%
run sparse_test.py

# %%
run erdos.py
# Out:
# (100, 1000)
# JI0=1.0 JII=-0.01

# %%
run training.py
# Out:
# /Users/shrisha/Documents/study/pytorchBN/proj/training.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   trainable_mask = torch.tensor(trainable_mask, dtype=torch.bool)
# torch.Size([1, 100, 1000])
# torch.Size([1, 1, 1000])
# u: 491
# 0.0 5.0609365 491
# 0
