# %%
run sparse_test.py
# Out:
# ffshape: torch.Size([1000])
# torch.Size([1, 1000])
# tmp2shape: torch.Size([1, 1000])
# torch.Size([1, 100, 1000])
# torch.Size([1, 1, 1000])
# JI0=1.0 JII=-0.01
# 9.0908985 9.0908985 0
# 0

# %%
run erdos.py
# Out:
# (100, 1000)
# JI0=1.0 JII=-0.01
