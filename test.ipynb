# %%
run sparse_test.py
# Out:
# torch.Size([1, 100, 1000])
# torch.Size([1, 1, 1000])
# JI0=1.0 JII=-0.01
# 6.2503066 11.305175 0
# 0

# %%
run erdos.py
# Out:
# (100, 1000)
# JI0=1.0 JII=-0.01

# %%
run dense_training.py
# Out:
# /Users/shrisha/Documents/study/pytorchBN/proj/dense_training.py:105: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   trainable_mask = torch.tensor(trainable_mask, dtype=torch.bool)
# Epoch [10/50], Loss: 0.4458
# Epoch [20/50], Loss: 0.0054
# Epoch [30/50], Loss: 0.0054
# Epoch [40/50], Loss: 0.0054
# Epoch [50/50], Loss: 0.0054
